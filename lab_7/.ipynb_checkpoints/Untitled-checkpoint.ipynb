# %% [markdown]
# # Univaariate Analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df.index,df['sepal.width'])
plt.show()

# %%
sns.scatterplot(x=df.index,y=df['sepal.width'],hue=df['variety'])
# Out:
# <Axes: xlabel='None', ylabel='sepal.width'>

# %%
sns.scatterplot(x=df.index,y=df['sepal.length'],hue=df['variety'])
# Out:
# <Axes: xlabel='None', ylabel='sepal.length'>

# %%
#line plot with markers
plt.figure(figsize=(6,6))
plt.xlabel('index',fontsize=20)
plt.ylabel('petal.length',fontsize=20)
plt.plot(df.index,df['petal.length'],markevery=1,marker='d')

for name,group in df.groupby('variety'):
    plt.plot(group.index,group['petal.length'],label=name,markevery=1,marker='d')

plt.legend()
plt.show()

# %%
#Setting title, figure size,labels and font size in seaborn
sns.set(rc={'figure.figsize':(7,7)})
sns.set(font_scale=1.5)
fig=sns.lineplot(x=df.index,y=df['petal.length'],markevery=1,marker='d',data=df,hue=df['variety'])
fig.set(xlabel='index')
# Out:
# [Text(0.5, 0, 'index')]

# %%
sns.stripplot(y=df['sepal.width'])
# Out:
# <Axes: ylabel='sepal.width'>

# %%
sns.stripplot(x=df['variety'],y=df['sepal.width'])
# Out:
# <Axes: xlabel='variety', ylabel='sepal.width'>

# %%
#swarm plot
sns.set(rc={'figure.figsize':(5,5)})
sns.swarmplot(x=df['sepal.width'])
# Out:
# <Axes: xlabel='sepal.width'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.swarmplot(x=df['variety'],y=df['sepal.width'])
# Out:
# <Axes: xlabel='variety', ylabel='sepal.width'>

# %%
#summary plot
#histogram

# %%
plt.hist(df['petal.width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['petal.width'],kde=False,color='black',bins=10)
# Out:
# C:\Users\ASHISH RAJ\AppData\Local\Temp\ipykernel_22284\2693374139.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal.width'],kde=False,color='black',bins=10)
# <Axes: xlabel='petal.width'>

# %%
#DENSITY PLOT
plt.figure(figsize=(5,5))
df['petal.length'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(df['petal.length'],shade=True)
# Out:
# C:\Users\ASHISH RAJ\AppData\Local\Temp\ipykernel_22284\176290844.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['petal.length'],shade=True)
# <Axes: xlabel='petal.length', ylabel='Density'>

# %%
#RUG PLOT
fig, ax = plt.subplots()
sns.rugplot(df['sepal.length'])
ax.set_xlim(3,9)
plt.show()

# %%
from scipy import stats
import numpy as np
kdf=df['sepal.length'].to_numpy()
rdf=np.hstack(kdf)
density = stats.kde.gaussian_kde(rdf)
x = np.arange(3,9,0.1)
plt.plot(x, density(x))
plt.plot(rdf,[0.01]*len(rdf),'|')
# Out:
# C:\Users\ASHISH RAJ\AppData\Local\Temp\ipykernel_22284\573612570.py:5: DeprecationWarning: Please import `gaussian_kde` from the `scipy.stats` namespace; the `scipy.stats.kde` namespace is deprecated and will be removed in SciPy 2.0.0.
#   density = stats.kde.gaussian_kde(rdf)

# %%
sns.distplot(df['sepal.length'],rug=True,hist=False)
# Out:
# C:\Users\ASHISH RAJ\AppData\Local\Temp\ipykernel_22284\2389858770.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal.length'],rug=True,hist=False)
# <Axes: xlabel='sepal.length', ylabel='Density'>

# %%
#BOX PLOT
plt.boxplot(df['sepal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25df163f950>,
#   <matplotlib.lines.Line2D at 0x25df2fc89e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x25df2fc9d60>,
#   <matplotlib.lines.Line2D at 0x25df2fcbcb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25df163de50>],
#  'medians': [<matplotlib.lines.Line2D at 0x25df2fc83b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25df2f9e360>],
#  'means': []}

# %%
#Removing the column with categorical variables
dfM=df.drop('variety',axis=1)
plt.figure(figsize=(9,9))

#Set Title
plt.title('Box plots of the 4 variables')
plt.boxplot(dfM.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
# Out:
# C:\Users\ASHISH RAJ\AppData\Local\Temp\ipykernel_22284\2407081727.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(dfM.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
# {'whiskers': [<matplotlib.lines.Line2D at 0x25df40d76b0>,
#   <matplotlib.lines.Line2D at 0x25df40d74d0>,
#   <matplotlib.lines.Line2D at 0x25df4085100>,
#   <matplotlib.lines.Line2D at 0x25df40859a0>,
#   <matplotlib.lines.Line2D at 0x25df409b1a0>,
#   <matplotlib.lines.Line2D at 0x25df3073b00>,
#   <matplotlib.lines.Line2D at 0x25df1778d40>,
#   <matplotlib.lines.Line2D at 0x25df177aea0>],
#  'caps': [<matplotlib.lines.Line2D at 0x25df40d57f0>,
#   <matplotlib.lines.Line2D at 0x25df40d6f90>,
#   <matplotlib.lines.Line2D at 0x25df4087d40>,
#   <matplotlib.lines.Line2D at 0x25df302c7d0>,
#   <matplotlib.lines.Line2D at 0x25df30711f0>,
#   <matplotlib.lines.Line2D at 0x25df3071910>,
#   <matplotlib.lines.Line2D at 0x25df16f86e0>,
#   <matplotlib.lines.Line2D at 0x25df17b9700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25df40c9d60>,
#   <matplotlib.lines.Line2D at 0x25df40d6fc0>,
#   <matplotlib.lines.Line2D at 0x25df40ab440>,
#   <matplotlib.lines.Line2D at 0x25df169ac00>],
#  'medians': [<matplotlib.lines.Line2D at 0x25df40d6270>,
#   <matplotlib.lines.Line2D at 0x25df302c350>,
#   <matplotlib.lines.Line2D at 0x25df2fe0c50>,
#   <matplotlib.lines.Line2D at 0x25df17bb3e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25df40d5040>,
#   <matplotlib.lines.Line2D at 0x25df40a99a0>,
#   <matplotlib.lines.Line2D at 0x25df2fe3e00>,
#   <matplotlib.lines.Line2D at 0x25df17bb140>],
#  'means': []}

# %%
sns.boxplot(df['sepal.width'])
# Out:
# <Axes: ylabel='sepal.width'>

# %%
sns.set(rc={'figure.figsize':(9,9)})
sns.boxplot(x="variable", y="value", data=pd.melt(dfM))
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
#distplot()
sns.set(rc={'figure.figsize':(6,6)})
sns.distplot(df['petal.length'],color='black',rug=True)
# Out:
# C:\Users\ASHISH RAJ\AppData\Local\Temp\ipykernel_22284\3262113193.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal.length'],color='black',rug=True)
# <Axes: xlabel='petal.length', ylabel='Density'>

# %%
#VIOLIN PLOT
plt.figure(figsize=(7,7))
plt.violinplot(dfM.values,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x25dee5f9a60>,
#   <matplotlib.collections.FillBetweenPolyCollection at 0x25df1d7b800>,
#   <matplotlib.collections.FillBetweenPolyCollection at 0x25df17cacf0>,
#   <matplotlib.collections.FillBetweenPolyCollection at 0x25df409bfe0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x25df488dca0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x25df1ded430>,
#  'cbars': <matplotlib.collections.LineCollection at 0x25df1d6ab10>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x25df1dee270>}

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(df['sepal.width'],orient='vertical')
# Out:
# <Axes: ylabel='sepal.width'>

# %%
sns.set(rc={'figure.figsize':(9,9)})
sns.violinplot(x=df['variety'], y=df['petal.width'],data=df)
# Out:
# <Axes: xlabel='variety', ylabel='petal.width'>

# %%
#Plots for categorical variables' analysis
#BAR PLOT
df['variety'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='variety'>

# %%
sns.countplot(df['variety'])
# Out:
# <Axes: xlabel='count', ylabel='variety'>

# %%
#PIE CHART
plt.pie(df['variety'].value_counts(),labels=['SETOSA','VERSICOLOR','VIRGINICA'],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x25df40d5dc0>,
#   <matplotlib.patches.Wedge at 0x25df201e330>,
#   <matplotlib.patches.Wedge at 0x25df51af020>],
#  [Text(0.5499999702695115, 0.9526279613277875, 'SETOSA'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'VERSICOLOR'),
#   Text(0.5500001486524352, -0.9526278583383436, 'VIRGINICA')])

# %%
df1=df.sample(frac=0.35)

plt.figure(figsize=(5,5))
plt.pie(df1['variety'].value_counts(),startangle=90,autopct='%.3f',labels=['SETOSA','VERSICOLOR','VIRGINICA'],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x25df5210230>,
#   <matplotlib.patches.Wedge at 0x25df51e4830>,
#   <matplotlib.patches.Wedge at 0x25df5211130>],
#  [Text(-1.003089820837103, 0.45145410767096644, 'SETOSA'),
#   Text(0.19828047925532238, -1.0819819090660805, 'VERSICOLOR'),
#   Text(0.9052822749848162, 0.6248711888047935, 'VIRGINICA')],
#  [Text(-0.5471399022747835, 0.2462476950932544, '36.538'),
#   Text(0.10815298868472129, -0.5901719503996802, '32.692'),
#   Text(0.4937903318098996, 0.3408388302571601, '30.769')])
